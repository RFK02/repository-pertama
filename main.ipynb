# %% [markdown]
# Ini adalah penjelasan dari sesuatu

# %% [markdown]
# # Heading 1
#
# ## Heading 2
#
# ### Heading 3
#
# **ini jadi bold**
#
# _ini jadi italic_

# %%
print("Hello world")
# Out:
# Hello world
